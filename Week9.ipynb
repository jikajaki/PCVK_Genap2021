# %% [markdown]
# <a href="https://colab.research.google.com/github/jikajaki/PCVK_Genap2021/blob/main/Week9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import cv2 as cv
from google.colab.patches import cv2_imshow
import numpy as np
import matplotlib.pyplot as plt
from skimage.io import imread, imshow
from skimage.morphology import (erosion, dilation, closing, opening,
                                area_closing, area_opening)
from skimage.color import rgb2gray

# %% [markdown]
# **Buatlah program implementasi operasi closing dengan Structuring Element berbentuk square 7 x 7 tanpa dan dengan menggunakan library morphology dari openCV, sehingga menghasilkan tampilan seperti di bawah ini: (Gunakan gambar j.png)**

# %%
img = cv.imread('/content/drive/MyDrive/PVCK/Images/j.png')

kernel = np.ones((7,7), np.uint8)
closing = cv.morphologyEx(img, cv.MORPH_CLOSE, kernel)

plt.subplot(121), plt.imshow(img), plt.title('Citra Awal')
plt.subplot(122), plt.imshow(closing), plt.title('Citra Hasil Closing')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7f966d2d12d0>,
#  <matplotlib.image.AxesImage at 0x7f966d2b1d50>,
#  Text(0.5, 1.0, 'Citra Hasil Closing'))

# %% [markdown]
# **Buatlah program implementasi operasi dilasi dengan Structuring Element berbentuk Cross 3 x 3 dan 5 x 5, sehingga menghasilkan tampilan seperti di bawah ini: (Gunakan gambar j.png)**

# %%
kernel = cv.getStructuringElement(cv.MORPH_CROSS, (3, 3))
cross3 = cv.morphologyEx(img, cv.MORPH_DILATE, kernel)

plt.subplot(121), plt.imshow(img), plt.title('Citra Awal')
plt.subplot(122), plt.imshow(cross3), plt.title('Citra Hasil Dilasi 3x3')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7f966cd7cd10>,
#  <matplotlib.image.AxesImage at 0x7f966cd7a0d0>,
#  Text(0.5, 1.0, 'Citra Hasil Dilasi 3x3'))

# %% [markdown]
# **Buatlah program implementasi operasi dilasi dengan Structuring Element berbentuk Circular 3 x 3 dan 5 x 5, sehingga menghasilkan tampilan seperti di bawah ini: (Gunakan gambar j.png)**

# %%
kernel = cv.getStructuringElement(cv.MORPH_ELLIPSE, (5, 5))
cross3 = cv.morphologyEx(img, cv.MORPH_DILATE, kernel)
plt.subplot(121), plt.imshow(img), plt.title('Citra Awal')
plt.subplot(122), plt.imshow(cross3), plt.title('Citra Hasil Circular 5x5')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7f966cc7fcd0>,
#  <matplotlib.image.AxesImage at 0x7f966cc546d0>,
#  Text(0.5, 1.0, 'Citra Hasil Circular 5x5'))

# %% [markdown]
# **Buatlah program implementasi operasi erosi dengan Structuring Element berbentuk Rectangle 3 x 5 dan 5 x 7, sehingga menghasilkan tampilan seperti di bawah ini: (Gunakan gambar j.png)**

# %%
kernel = cv.getStructuringElement(cv.MORPH_RECT, (5, 7))
cross3 = cv.morphologyEx(img, cv.MORPH_ERODE, kernel)
plt.subplot(121), plt.imshow(img), plt.title('Citra Awal')
plt.subplot(122), plt.imshow(cross3), plt.title('Citra Hasil Rectangle 5x7')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7f966cc54b90>,
#  <matplotlib.image.AxesImage at 0x7f966cba7d90>,
#  Text(0.5, 1.0, 'Citra Hasil Rectangle 5x7'))

# %% [markdown]
# **Buatlah program implementasi operasi erosi dengan Structuring Element berbentuk Line Vertikal 3 dan 5, sehingga menghasilkan tampilan seperti di bawah ini: (Gunakan gambar j.png)**

# %%
kernel = cv.getStructuringElement(cv.MORPH_RECT, (5, 7))
cross3 = cv.morphologyEx(img, cv.MORPH_ERODE, kernel)

plt.subplot(121), plt.imshow(img), plt.title('Citra Awal')
plt.subplot(122), plt.imshow(cross3), plt.title('Citra Hasil Rectangle 5x7')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7f966c9fcc90>,
#  <matplotlib.image.AxesImage at 0x7f966c9d2650>,
#  Text(0.5, 1.0, 'Citra Hasil Rectangle 5x7'))
